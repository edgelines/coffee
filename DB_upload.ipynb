# %%
import pandas as pd

pd.read_csv('coffee.csv').fillna('-')
# Out:
#             국가                                                 지역  \
# 0        에티오피아                                                시다모
# 1        에티오피아                                         구지 샤키소 다사야
# 2           페루                                               세로아줄
# 3        에티오피아                                                아바야
# 4        에티오피아                                                아바야
# 5         과테말라                                    산타로사 라구나 데 아야르자
# 6        에티오피아                                             리무 볼렌소
# 7        에티오피아                                             구지 겔레나
# 8          르완다                                          부산제, 냐루구루
# 9        에티오피아                          리무 : 넵소 아바데가 (짐마,곰마,케디메사)
# 10  BRICK 블랜드                     에디오피아(25%), 브라질(25%), 콜롬비아(50%)
# 11       에티오피아                                     예가체프, 게데오, 아리차
# 12         블랜드               브라질 세하도 몬테 카르멜로 85% 과테말라 라고 아티틀란 15%
# ...
